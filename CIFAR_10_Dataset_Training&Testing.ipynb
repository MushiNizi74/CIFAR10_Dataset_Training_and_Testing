# %%
import pandas as pd #importing all important packagages
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from skimage.feature import hog
from sklearn.metrics import accuracy_score
from keras import datasets, Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from sklearn import svm
import tensorflow as tf 
import skimage.feature

# %%
from google.colab import drive    #mounting the google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = np.load('/content/drive/MyDrive/Coursework/trnImage.npy')    #loading training image files
trnlabel_coarse = np.load('/content/drive/MyDrive/Coursework/trnLabel_coarse.npy')
trnlabel_fine = np.load('/content/drive/MyDrive/Coursework/trnLabel_fine.npy')

tstImage= np.load('/content/drive/MyDrive/Coursework/tstImage.npy')   #loading testing image files
tstLabel_fine= np.load('/content/drive/MyDrive/Coursework/tstLabel_fine.npy')
testLabel_coarse= np.load('/content/drive/MyDrive/Coursework/tstLabel_coarse.npy')

# %%
transposed = np.transpose(data, [3,0,1,2])  #transposing data to work with indexing within the model
print(f'Shape of transposed: {transposed.shape}')

trasnsposed_tst=np.transpose(tstImage, [3,0,1,2]) #printing to check the shape of the newly transposed data
# Out:
# Shape of transposed: (50000, 32, 32, 3)

# %% [markdown]
# # **CNN**

# %%
from keras.layers.core.dropout import Dropout     
batch_size = 50 #Setting up batch size for faster processing
loss_function = sparse_categorical_crossentropy #better projection of loss
no_classes = 100  #classes for coarse dataset
verbosity = 1 #wanting to see output while training
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))  #first layer of CNN
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.6))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))  #second layer of CNN
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.6))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu')) #third layer of CNN
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.6)) 
model.add(Flatten())                                          #flattening the dataset
model.add(Dense(256, activation='relu'))                      #Density layers 
model.add(Dense(128, activation='relu'))
model.add(Dense(no_classes, activation='softmax'))

# %%
TLF = tf.keras.utils.to_categorical(trnlabel_coarse,100)      #Tuning the dataset
print(TLF.shape)
# Out:
# (50000, 100)

# %%
opt='adam'                                                     #setting optimizer
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

history= model.fit(transposed,TLF, epochs=30, batch_size=batch_size,  #fitting the model of data
            verbose=verbosity, validation_split=0.2)
# Out:
# Epoch 1/30
# 800/800 [==============================] - 15s 5ms/step - loss: 2.8053 - accuracy: 0.1254 - val_loss: 2.7711 - val_accuracy: 0.1593
# Epoch 2/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.5311 - accuracy: 0.2101 - val_loss: 2.5699 - val_accuracy: 0.2203
# Epoch 3/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.4314 - accuracy: 0.2453 - val_loss: 2.4842 - val_accuracy: 0.2464
# Epoch 4/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.3657 - accuracy: 0.2629 - val_loss: 2.4689 - val_accuracy: 0.2478
# Epoch 5/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.3164 - accuracy: 0.2793 - val_loss: 2.3516 - val_accuracy: 0.2770
# Epoch 6/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.2766 - accuracy: 0.2916 - val_loss: 2.4211 - val_accuracy: 0.2650
# Epoch 7/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.2486 - accuracy: 0.2964 - val_loss: 2.3774 - val_accuracy: 0.2844
# Epoch 8/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.2198 - accuracy: 0.3115 - val_loss: 2.3267 - val_accuracy: 0.2939
# Epoch 9/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.2056 - accuracy: 0.3152 - val_loss: 2.3221 - val_accuracy: 0.3022
# Epoch 10/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.1761 - accuracy: 0.3219 - val_loss: 2.3692 - val_accuracy: 0.2875
# Epoch 11/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.1618 - accuracy: 0.3270 - val_loss: 2.2996 - val_accuracy: 0.3058
# Epoch 12/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.1479 - accuracy: 0.3320 - val_loss: 2.2489 - val_accuracy: 0.3257
# Epoch 13/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.1308 - accuracy: 0.3380 - val_loss: 2.2957 - val_accuracy: 0.3181
# Epoch 14/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.1166 - accuracy: 0.3377 - val_loss: 2.2305 - val_accuracy: 0.3313
# Epoch 15/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.1084 - accuracy: 0.3435 - val_loss: 2.2120 - val_accuracy: 0.3370
# Epoch 16/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0952 - accuracy: 0.3473 - val_loss: 2.2402 - val_accuracy: 0.3229
# Epoch 17/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0806 - accuracy: 0.3522 - val_loss: 2.1759 - val_accuracy: 0.3432
# Epoch 18/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0790 - accuracy: 0.3519 - val_loss: 2.2395 - val_accuracy: 0.3210
# Epoch 19/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0659 - accuracy: 0.3575 - val_loss: 2.1162 - val_accuracy: 0.3617
# Epoch 20/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0565 - accuracy: 0.3605 - val_loss: 2.1802 - val_accuracy: 0.3355
# Epoch 21/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0536 - accuracy: 0.3602 - val_loss: 2.1481 - val_accuracy: 0.3598
# Epoch 22/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0462 - accuracy: 0.3596 - val_loss: 2.2014 - val_accuracy: 0.3380
# Epoch 23/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0439 - accuracy: 0.3626 - val_loss: 2.2720 - val_accuracy: 0.3182
# Epoch 24/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0371 - accuracy: 0.3661 - val_loss: 2.1667 - val_accuracy: 0.3484
# Epoch 25/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0293 - accuracy: 0.3697 - val_loss: 2.2200 - val_accuracy: 0.3325
# Epoch 26/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0255 - accuracy: 0.3715 - val_loss: 2.1277 - val_accuracy: 0.3562
# Epoch 27/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0168 - accuracy: 0.3744 - val_loss: 2.2245 - val_accuracy: 0.3272
# Epoch 28/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0171 - accuracy: 0.3705 - val_loss: 2.1533 - val_accuracy: 0.3481
# Epoch 29/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0066 - accuracy: 0.3773 - val_loss: 2.1305 - val_accuracy: 0.3539
# Epoch 30/30
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0087 - accuracy: 0.3736 - val_loss: 2.1021 - val_accuracy: 0.3612

# %%
plt.figure(figsize=[10,5])                            #plotting the figure
plt.subplot(121)
plt.plot(history.history['val_accuracy'])
plt.plot(history.history['accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy',
           'Validation Accuracy'])
plt.title('Accuracy Curves')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss',
           'Validation Loss'])
plt.title('Loss Curves')
plt.show()

# %%
from keras.layers.core.dropout import Dropout
batch_size = 50
loss_function = sparse_categorical_crossentropy
no_classes = 100
verbosity = 1
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.6))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.6))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(no_classes, activation='softmax'))

# %%
TLF2 = tf.keras.utils.to_categorical(trnlabel_fine)
print(TLF2.shape)
print(transposed.shape)
# Out:
# (50000, 100)
# (50000, 32, 32, 3)

# %%
opt='adam'
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

history2= model.fit(transposed,TLF2, epochs=70, batch_size=batch_size,
            verbose=verbosity, validation_split=0.2)
# Out:
# Epoch 1/70
# 800/800 [==============================] - 5s 5ms/step - loss: 4.2843 - accuracy: 0.0376 - val_loss: 4.0926 - val_accuracy: 0.0684
# Epoch 2/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.9150 - accuracy: 0.0877 - val_loss: 3.9764 - val_accuracy: 0.0818
# Epoch 3/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.7316 - accuracy: 0.1191 - val_loss: 3.7688 - val_accuracy: 0.1213
# Epoch 4/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.6107 - accuracy: 0.1393 - val_loss: 3.6140 - val_accuracy: 0.1502
# Epoch 5/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.5145 - accuracy: 0.1564 - val_loss: 3.6131 - val_accuracy: 0.1606
# Epoch 6/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.4474 - accuracy: 0.1694 - val_loss: 3.7136 - val_accuracy: 0.1418
# Epoch 7/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.3846 - accuracy: 0.1794 - val_loss: 3.6610 - val_accuracy: 0.1567
# Epoch 8/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.3369 - accuracy: 0.1918 - val_loss: 3.4045 - val_accuracy: 0.1924
# Epoch 9/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.2968 - accuracy: 0.1968 - val_loss: 3.4111 - val_accuracy: 0.1935
# Epoch 10/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.2559 - accuracy: 0.2062 - val_loss: 3.3716 - val_accuracy: 0.1921
# Epoch 11/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.2282 - accuracy: 0.2090 - val_loss: 3.3088 - val_accuracy: 0.2037
# Epoch 12/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.1943 - accuracy: 0.2156 - val_loss: 3.3481 - val_accuracy: 0.1956
# Epoch 13/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.1739 - accuracy: 0.2203 - val_loss: 3.2823 - val_accuracy: 0.2079
# Epoch 14/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.1461 - accuracy: 0.2227 - val_loss: 3.3805 - val_accuracy: 0.1986
# Epoch 15/70
# 800/800 [==============================] - 5s 6ms/step - loss: 3.1252 - accuracy: 0.2274 - val_loss: 3.2210 - val_accuracy: 0.2291
# Epoch 16/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.1166 - accuracy: 0.2278 - val_loss: 3.3040 - val_accuracy: 0.2166
# Epoch 17/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.0918 - accuracy: 0.2329 - val_loss: 3.2376 - val_accuracy: 0.2272
# Epoch 18/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.0746 - accuracy: 0.2382 - val_loss: 3.3520 - val_accuracy: 0.2005
# Epoch 19/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.0756 - accuracy: 0.2378 - val_loss: 3.1881 - val_accuracy: 0.2354
# Epoch 20/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.0572 - accuracy: 0.2402 - val_loss: 3.2161 - val_accuracy: 0.2288
# Epoch 21/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.0388 - accuracy: 0.2447 - val_loss: 3.2010 - val_accuracy: 0.2286
# Epoch 22/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.0370 - accuracy: 0.2436 - val_loss: 3.2174 - val_accuracy: 0.2289
# Epoch 23/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.0168 - accuracy: 0.2463 - val_loss: 3.1207 - val_accuracy: 0.2432
# Epoch 24/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.0164 - accuracy: 0.2500 - val_loss: 3.1138 - val_accuracy: 0.2439
# Epoch 25/70
# 800/800 [==============================] - 4s 5ms/step - loss: 3.0048 - accuracy: 0.2533 - val_loss: 3.0599 - val_accuracy: 0.2485
# Epoch 26/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9879 - accuracy: 0.2538 - val_loss: 3.1098 - val_accuracy: 0.2407
# Epoch 27/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9888 - accuracy: 0.2507 - val_loss: 3.1256 - val_accuracy: 0.2474
# Epoch 28/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9696 - accuracy: 0.2571 - val_loss: 3.1128 - val_accuracy: 0.2491
# Epoch 29/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9658 - accuracy: 0.2560 - val_loss: 3.1713 - val_accuracy: 0.2368
# Epoch 30/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9598 - accuracy: 0.2576 - val_loss: 3.2250 - val_accuracy: 0.2316
# Epoch 31/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9511 - accuracy: 0.2600 - val_loss: 3.1329 - val_accuracy: 0.2538
# Epoch 32/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9377 - accuracy: 0.2642 - val_loss: 3.0129 - val_accuracy: 0.2633
# Epoch 33/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9386 - accuracy: 0.2623 - val_loss: 3.0831 - val_accuracy: 0.2531
# Epoch 34/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9283 - accuracy: 0.2615 - val_loss: 3.0134 - val_accuracy: 0.2573
# Epoch 35/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9226 - accuracy: 0.2681 - val_loss: 3.0933 - val_accuracy: 0.2499
# Epoch 36/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9005 - accuracy: 0.2691 - val_loss: 3.0713 - val_accuracy: 0.2610
# Epoch 37/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9077 - accuracy: 0.2695 - val_loss: 3.0468 - val_accuracy: 0.2596
# Epoch 38/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.9052 - accuracy: 0.2706 - val_loss: 3.0611 - val_accuracy: 0.2579
# Epoch 39/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8950 - accuracy: 0.2721 - val_loss: 3.0109 - val_accuracy: 0.2655
# Epoch 40/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8988 - accuracy: 0.2702 - val_loss: 2.9862 - val_accuracy: 0.2705
# Epoch 41/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8910 - accuracy: 0.2736 - val_loss: 2.9527 - val_accuracy: 0.2748
# Epoch 42/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8782 - accuracy: 0.2763 - val_loss: 3.0555 - val_accuracy: 0.2651
# Epoch 43/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8803 - accuracy: 0.2766 - val_loss: 3.1062 - val_accuracy: 0.2536
# Epoch 44/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8671 - accuracy: 0.2743 - val_loss: 3.0322 - val_accuracy: 0.2608
# Epoch 45/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8773 - accuracy: 0.2730 - val_loss: 2.9948 - val_accuracy: 0.2634
# Epoch 46/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8624 - accuracy: 0.2770 - val_loss: 3.1696 - val_accuracy: 0.2448
# Epoch 47/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8737 - accuracy: 0.2737 - val_loss: 2.9841 - val_accuracy: 0.2691
# Epoch 48/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8715 - accuracy: 0.2740 - val_loss: 2.9754 - val_accuracy: 0.2718
# Epoch 49/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8578 - accuracy: 0.2764 - val_loss: 2.9396 - val_accuracy: 0.2772
# Epoch 50/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8495 - accuracy: 0.2798 - val_loss: 3.0063 - val_accuracy: 0.2719
# Epoch 51/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8520 - accuracy: 0.2770 - val_loss: 3.0175 - val_accuracy: 0.2619
# Epoch 52/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8484 - accuracy: 0.2781 - val_loss: 3.0334 - val_accuracy: 0.2677
# Epoch 53/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8443 - accuracy: 0.2812 - val_loss: 2.9861 - val_accuracy: 0.2698
# Epoch 54/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8332 - accuracy: 0.2830 - val_loss: 2.9866 - val_accuracy: 0.2688
# Epoch 55/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8537 - accuracy: 0.2793 - val_loss: 3.0804 - val_accuracy: 0.2580
# Epoch 56/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8349 - accuracy: 0.2824 - val_loss: 3.0027 - val_accuracy: 0.2700
# Epoch 57/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8304 - accuracy: 0.2839 - val_loss: 2.9380 - val_accuracy: 0.2784
# Epoch 58/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8336 - accuracy: 0.2806 - val_loss: 3.0392 - val_accuracy: 0.2659
# Epoch 59/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8291 - accuracy: 0.2813 - val_loss: 2.9403 - val_accuracy: 0.2830
# Epoch 60/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8294 - accuracy: 0.2849 - val_loss: 2.9295 - val_accuracy: 0.2791
# Epoch 61/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8227 - accuracy: 0.2853 - val_loss: 2.9142 - val_accuracy: 0.2868
# Epoch 62/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8110 - accuracy: 0.2874 - val_loss: 2.9933 - val_accuracy: 0.2685
# Epoch 63/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8134 - accuracy: 0.2857 - val_loss: 2.9172 - val_accuracy: 0.2865
# Epoch 64/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8148 - accuracy: 0.2863 - val_loss: 2.9267 - val_accuracy: 0.2822
# Epoch 65/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8139 - accuracy: 0.2855 - val_loss: 2.9576 - val_accuracy: 0.2753
# Epoch 66/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8027 - accuracy: 0.2865 - val_loss: 3.0817 - val_accuracy: 0.2537
# Epoch 67/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8043 - accuracy: 0.2891 - val_loss: 2.9163 - val_accuracy: 0.2817
# Epoch 68/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8113 - accuracy: 0.2882 - val_loss: 2.8114 - val_accuracy: 0.2993
# Epoch 69/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.7971 - accuracy: 0.2873 - val_loss: 2.9190 - val_accuracy: 0.2811
# Epoch 70/70
# 800/800 [==============================] - 4s 5ms/step - loss: 2.7912 - accuracy: 0.2923 - val_loss: 2.8912 - val_accuracy: 0.2896

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (50, 30, 30, 32)          896
#
#  max_pooling2d_3 (MaxPooling  (50, 15, 15, 32)         0
#  2D)
#
#  dropout_3 (Dropout)         (50, 15, 15, 32)          0
#
#  conv2d_4 (Conv2D)           (50, 13, 13, 64)          18496
#
#  max_pooling2d_4 (MaxPooling  (50, 6, 6, 64)           0
#  2D)
#
#  dropout_4 (Dropout)         (50, 6, 6, 64)            0
#
#  conv2d_5 (Conv2D)           (50, 4, 4, 128)           73856
#
#  max_pooling2d_5 (MaxPooling  (50, 2, 2, 128)          0
#  2D)
#
#  dropout_5 (Dropout)         (50, 2, 2, 128)           0
#
#  flatten_1 (Flatten)         (50, 512)                 0
#
#  dense_3 (Dense)             (50, 256)                 131328
#
#  dense_4 (Dense)             (50, 128)                 32896
#
#  dense_5 (Dense)             (50, 100)                 12900
#
# =================================================================
# Total params: 270,372
# Trainable params: 270,372
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=[10,5])        #plotting the figure
plt.subplot(121)
plt.plot(history2.history['val_accuracy'])
plt.plot(history2.history['accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy',
           'Validation Accuracy'])
plt.title('Accuracy Curves')

plt.subplot(122)
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss',
           'Validation Loss'])
plt.title('Loss Curves')
plt.show()

# %% [markdown]
# # SVM Training

# %%
train_hog=[]
test_hog=[]

for i in range (len(transposed)):
  hog_feature, hog_image = skimage.feature.hog(transposed[i], pixels_per_cell=[6,6],cells_per_block=[2,2], visualize=True, multichannel=True)
  train_hog.append(hog_feature)

# %%
for i in range (len(trasnsposed_tst)):
  hog_feature, hog_image = skimage.feature.hog(trasnsposed_tst[i], pixels_per_cell=[6,6],cells_per_block=[2,2], visualize=True, multichannel=True)
  test_hog.append(hog_feature)

# %%
SVM_model1=svm.SVC(kernel="linear")
SVM_model1.fit(train_hog,trnlabel_fine)
Prediction= SVM_model1.predict(test_hog)
Prediction
# Out:
# array([49, 33, 44, ..., 19, 63, 64])

# %%
acci= accuracy_score(tstLabel_fine, Prediction)
print(acci)
# Out:
# 0.2161

# %%
coarse_train_hog=[]
coarse_test_hog=[]

for i in range (len(transposed)):
  hog_feature, hog_image = skimage.feature.hog(transposed[i], pixels_per_cell=[6,6],cells_per_block=[2,2], visualize=True, multichannel=True)
  coarse_train_hog.append(hog_feature)

# %%
for i in range (len(trasnsposed_tst)):
  hog_feature, hog_image = skimage.feature.hog(trasnsposed_tst[i], pixels_per_cell=[6,6],cells_per_block=[2,2], visualize=True, multichannel=True)
  coarse_test_hog.append(hog_feature)

# %%
SVM_model2=svm.SVC(kernel="linear")
SVM_model2.fit(coarse_train_hog,trnlabel_coarse)
Prediction2= SVM_model2.predict(coarse_test_hog)
Prediction2
# Out:
# array([ 9, 17, 14, ..., 11,  8, 12])

# %%
acci= accuracy_score(testLabel_coarse, Prediction)
print(acci)
# Out:
# 0.0139

# %% [markdown]
# # **REFERENCES**
#
# https://www.youtube.com/watch?v=EJIrUMB9c1k&t=194s
#
# https://medium.com/analytics-vidhya/image-classification-using-machine-learning-support-vector-machine-svm-dc7a0ec92e01
#
# https://notebook.community/sonapraneeth-a/object-classification/jupyter_notebooks/svm/02_SVM_HOG_Features_CIFAR_10
#
# https://scikit-image.org/docs/stable/auto_examples/features_detection/plot_hog.html
#
# https://www.youtube.com/watch?v=fM4gg8K7CWc
